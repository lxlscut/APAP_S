# %%
import cv2
help(cv2.SVDecomp)
# Out:
# Help on built-in function SVDecomp:
#
# SVDecomp(...)
#     SVDecomp(src[, w[, u[, vt[, flags]]]]) -> w, u, vt
#     .   wrap SVD::compute

# %%
def ransac(p=0.990, epsilon=0.5, threshold=5, src_point=None, dst_point=None):
